# %%
import json
import pandas as pd
from sklearn.manifold import TSNE
from pathlib import Path
from urllib.request import urlopen

# %%
def load_dota2_hero_data():
    try:
        response = urlopen('https://api.opendota.com/api/heroStats')

        if response.getcode() == 200:
            # Parse JSON in Python
            data = json.loads(response.read().decode('utf-8'))
            df = pd.DataFrame(data)

    except Exception as e:
        print(str(e))
        df = pd.read_json("dota2-heros-raw.json")

    df = df.drop(columns=["img", "icon", "cm_enabled", "roles", "turbo_picks_trend", "turbo_wins_trend", "pub_pick_trend", "pub_win_trend"])
    df["name"] = df["name"].apply(lambda x: x[len("npc_dota_hero_"):])

    return df

# %%
def project(df):
    tsne = TSNE(n_components=2, perplexity=float(max(10.0, min(50.0, df.shape[0] / 5))))
    result = tsne.fit_transform(df.to_numpy())
    return result

def process(df):
    ndf = df.copy()
    cols = df.dtypes[(df.dtypes == "object") | (df.dtypes == "str")].index.values
    for c in cols:
        vals = df[c].unique().tolist()
        ndf[c] = df[c].apply(lambda x: vals.index(x))

    return ndf.fillna(0)

def transform_all(names):
    for n in names:
        file = Path(f"../public/data/{n}.csv")
        df = pd.read_csv(file)
        ndf = process(df)
        print(ndf)
        coords = project(ndf)
        df["x"] = coords[:,0]
        df["y"] = coords[:,1]
        df.to_csv(file.with_suffix(".dr.csv"), index=False)

# %%
df = load_dota2_hero_data()
ndf = process(df)
coords = project(ndf)
df["x"] = coords[:,0]
df["y"] = coords[:,1]
df.to_csv("dota2-heros.csv", index=False)
df
# Out:
# HTTP Error 403: Forbidden
#       id            name primary_attr attack_type  base_health  \
# 0      1        antimage          agi       Melee          120
# 1      2             axe          str       Melee          120
# 2      3            bane          all      Ranged          120
# 3      4     bloodseeker          agi       Melee          120
# 4      5  crystal_maiden          int      Ranged          120
# ..   ...             ...          ...         ...          ...
# 122  136           marci          all       Melee          120
# 123  137    primal_beast          str       Melee          120
# 124  138          muerta          int      Ranged          120
# 125  145             kez          agi       Melee          120
# 126  155           largo          str       Melee          120
#
#      base_health_regen  base_mana  base_mana_regen  base_armor  base_mr  ...  \
# 0                 1.00         75             0.00           1       25  ...
# 1                 2.50         75             0.00           0       25  ...
# 2                 0.25         75             0.00           1       25  ...
# 3                 0.25         75             0.00           2       25  ...
# 4                 0.25         75             0.00           0       25  ...
# ..                 ...        ...              ...         ...      ...  ...
# 122               0.25         75             0.00           0       25  ...
# 123               0.25         75             0.00           2       25  ...
# 124               0.25         75             0.00           0       25  ...
# 125               1.50         75             0.25           1       25  ...
# 126               0.25         75             0.00           2       25  ...
#
#      8_win  turbo_picks  turbo_wins  pro_pick  pro_win  pro_ban  pub_pick  \
# 0        0       171491       89484        17        7       35    438097
# 1        0       195041      100179        38       16       14    544108
# 2        0        35091       16313        23       13       43     71615
# 3        0        83498       40583         7        2        6    151117
# 4        0       152932       77594        39       16        2    326143
# ..     ...          ...         ...       ...      ...      ...       ...
# 122      0        72553       33286        41       18      103    190273
# 123      0        54834       27485        34       17       62    123493
# 124      0        88846       46686        34       20       36    172367
# 125      0        79522       36949        49       20       48    201232
# 126      0        60044       30641        81       40      156    184854
#
#      pub_win          x         y
# 0     222363   9.187915  6.923479
# 1     278687  10.494372  8.156430
# 2      34725  -9.902211 -8.442541
# 3      76791  -2.546175 -4.153138
# 4     164112   6.902194  4.709567
# ..       ...        ...       ...
# 122    94946  -1.220656 -1.124068
# 123    59454  -6.775765 -6.201919
# 124    83354  -1.378748 -2.938020
# 125    95905  -0.383995 -0.527285
# 126    96494  -2.561719 -0.772727
#
# [127 rows x 54 columns]

# %%
path = Path("games.json")
df = pd.read_json(path)
# df["cluster"] = df["cluster"].apply(lambda x: max(x, key=lambda y: y["value"])["name"] if len(x) > 0 else "none")
tagNames = {}

# collect tags names
for _, d in df.iterrows():
    for t in d["tags"]:
        tagNames[t["id"]] = t["name"]

tagList = [tid for tid in tagNames.keys()]

# get values
tags = [["false" for _ in range(df.shape[0])] for _ in tagList]

for i, d in df.iterrows():
    for t in d["tags"]:
        j = tagList.index(t["id"])
        tags[j][i] = "true"

df.drop(columns=["tags"], inplace=True)
idx = 0
for tid in tagList:
    df[tagNames[tid]] = tags[idx]
    idx += 1

df.to_csv(Path("../frontend/public/data/games.dr.csv"), index=False)
df
# Out:
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
# C:\Users\beckerfa\AppData\Local\Temp\ipykernel_16672\1928762695.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[tagNames[tid]] = tags[idx]
#              x          y     id                                     name  \
# 0     2.475226  39.429377      1                                Her Story
# 1    12.795586  31.484822      2                               L.A. Noire
# 2    14.175375  18.145728      3                        The Wolf Among Us
# 3     4.521480  23.224236      4    Sherlock Holmes: Crimes & Punishments
# 4     8.382424  28.223076      5    Sherlock Holmes: Consulting Detective
# ..         ...        ...    ...                                      ...
# 405  -3.461982  33.388970  13393                              THE LONGING
# 406  28.193400  12.283127  13395                     Post Für Ritter Rost
# 407   1.840349 -32.086700  13398                                 Palworld
# 408 -14.406370 -10.209032  13399  Call of Duty®: Modern Warfare® 2 (2009)
# 409   6.396437 -35.328213  13401                          Animal Crossing
#
#     chunk: continuous exp: homogeneous ginfo: exploration  \
# 0                true             true               true
# 1               false             true               true
# 2               false             true               true
# 3               false             true               true
# 4               false             true               true
# ..                ...              ...                ...
# 405              true             true               true
# 406             false            false               true
# 407              true            false               true
# 408             false             true              false
# 409              true             true              false
#
#     ginfo: remember self ginfo: text search goc: none  ... vision: other  \
# 0                   true               true      true  ...         false
# 1                  false              false     false  ...         false
# 2                  false              false     false  ...         false
# 3                  false              false     false  ...         false
# 4                   true              false     false  ...         false
# ..                   ...                ...       ...  ...           ...
# 405                false              false     false  ...         false
# 406                false              false     false  ...         false
# 407                false              false     false  ...         false
# 408                false              false     false  ...         false
# 409                false              false      true  ...         false
#
#     struc: turnbased top: art set-g: steampunk set-s: underwater  \
# 0              false    false            false             false
# 1              false    false            false             false
# 2              false    false            false             false
# 3              false    false            false             false
# 4              false    false            false             false
# ..               ...      ...              ...               ...
# 405            false    false            false             false
# 406            false    false            false             false
# 407            false    false            false             false
# 408            false    false            false             false
# 409            false    false            false             false
#
#     set-s: africa mini: strategy top: sports set-t: antiquity  \
# 0           false          false       false            false
# 1           false          false       false            false
# 2           false          false       false            false
# 3           false          false       false            false
# 4           false          false       false            false
# ..            ...            ...         ...              ...
# 405         false          false       false            false
# 406         false          false       false            false
# 407         false          false       false            false
# 408         false          false       false            false
# 409         false          false       false            false
#
#     com: free gestures
# 0                false
# 1                false
# 2                false
# 3                false
# 4                false
# ..                 ...
# 405              false
# 406              false
# 407              false
# 408              false
# 409              false
#
# [410 rows x 229 columns]

# %%
dft = pd.read_json(Path("games.tags.json"))
dft.to_csv(Path("../backend/data/games.tags.csv"), index=False)
dft
# Out:
#        id               name  \
# 0    1035    ai: commandable
# 1    1036  ai: uncommandable
# 2    1037     auto: assemble
# 3    1038    auto: configure
# 4    1050   character editor
# ..    ...                ...
# 220  1326      wyd: fighting
# 221  1327      wyd: managing
# 222  1328   wyd: platforming
# 223  1329      wyd: puzzling
# 224  1330        wyd: racing
#
#                                            description
# 0    the game has AI companions that can be command...
# 1    the game has AI companions that CANNOT be comm...
# 2    automation is directly build/assembled, usuall...
# 3    automation is configured but not directly buil...
# 4    the game has a character editor which allows t...
# ..                                                 ...
# 220  the player does a lot of fighting, be it melee...
# 221  the player does a lot of managing, e.g. hiring...
# 222  the player does a lot of platforming, e.g. jum...
# 223  the player does a lot of puzzling, e.g. they n...
# 224  the player does a lot of racing with some kind...
#
# [225 rows x 3 columns]

# %%
# files = ["iris", "heart_disease_uci", "cereal", "anxiety_depression"]
files = ["cereal"]
transform_all(files)
# Out:
#     name  manufacturer  type  calories  protein  fat  sodium  fiber  carbs  \
# 0      0             0     0        70        4    1     130   10.0    5.0
# 1      1             1     0       120        3    5      15    2.0    8.0
# 2      2             2     0        70        4    1     260    9.0    7.0
# 3      3             2     0        50        4    0     140   14.0    8.0
# 4      4             3     0       110        2    2     200    1.0   14.0
# ..   ...           ...   ...       ...      ...  ...     ...    ...    ...
# 72    72             4     0       110        2    1     250    0.0   21.0
# 73    73             4     0       110        1    1     140    0.0   13.0
# 74    74             3     0       100        3    1     230    3.0   17.0
# 75    75             4     0       100        3    1     200    3.0   17.0
# 76    76             4     0       110        2    1     200    1.0   16.0
#
#     sugars  potassium  vitamins&minerals  display shelf  weight  cups  \
# 0        6        280                 25              3     1.0  0.33
# 1        8        135                  0              3     1.0  1.00
# 2        5        320                 25              3     1.0  0.33
# 3        0        330                 25              3     1.0  0.50
# 4        8         -1                 25              3     1.0  0.75
# ..     ...        ...                ...            ...     ...   ...
# 72       3         60                 25              3     1.0  0.75
# 73      12         25                 25              2     1.0  1.00
# 74       3        115                 25              1     1.0  0.67
# 75       3        110                 25              1     1.0  1.00
# 76       8         60                 25              1     1.0  0.75
#
#        rating
# 0   68.402973
# 1   33.983679
# 2   59.425505
# 3   93.704912
# 4   34.384843
# ..        ...
# 72  39.106174
# 73  27.753301
# 74  49.787445
# 75  51.592193
# 76  36.187559
#
# [77 rows x 16 columns]

# %%
file = Path("../public/data/anxiety_depression.csv")
df = pd.read_csv(file)
df
# Out:
#       Age  Gender Education_Level Employment_Status  Sleep_Hours  \
# 0      56    Male      Bachelor's        Unemployed          6.0
# 1      69  Female      Bachelor's           Retired          8.8
# 2      46  Female        Master's          Employed          5.3
# 3      32  Female     High School        Unemployed          8.8
# 4      60  Female      Bachelor's           Retired          7.2
# ...   ...     ...             ...               ...          ...
# 1195   23  Female           Other           Student          5.1
# 1196   43  Female        Master's          Employed          8.9
# 1197   71  Female             PhD           Retired          6.0
# 1198   21    Male           Other          Employed          8.5
# 1199   36    Male           Other          Employed          4.4
#
#       Physical_Activity_Hrs  Social_Support_Score  Anxiety_Score  \
# 0                       0.4                     3              4
# 1                       2.8                     6             18
# 2                       1.6                     5              5
# 3                       0.5                     4              6
# 4                       0.7                     2              7
# ...                     ...                   ...            ...
# 1195                    0.1                     7             16
# 1196                    0.4                     9             19
# 1197                    0.1                     2             15
# 1198                    2.7                     8             12
# 1199                    2.6                     7             10
#
#       Depression_Score  Stress_Level  ...  Chronic_Illnesses  Medication_Use  \
# 0                    2             9  ...                  0            None
# 1                    7             6  ...                  0            None
# 2                   13             8  ...                  0            None
# 3                    3             4  ...                  1            None
# 4                   15             3  ...                  0            None
# ...                ...           ...  ...                ...             ...
# 1195                15             5  ...                  0      Occasional
# 1196                 4             9  ...                  0            None
# 1197                 4             2  ...                  0            None
# 1198                20             2  ...                  1            None
# 1199                10             5  ...                  0            None
#
#      Therapy  Meditation  Substance_Use Financial_Stress  Work_Stress  \
# 0          0           1           None                4            3
# 1          1           0           None                1            4
# 2          0           1           None                8            7
# 3          0           0           None                7            4
# 4          1           1       Frequent                8            9
# ...      ...         ...            ...              ...          ...
# 1195       0           0           None                2            8
# 1196       0           1           None                8            9
# 1197       0           1           None                2            9
# 1198       0           0           None                8            5
# 1199       1           0       Frequent                7            2
#
#       Self_Esteem_Score  Life_Satisfaction_Score  Loneliness_Score
# 0                     7                        5                 1
# 1                     7                        4                 6
# 2                     8                        1                 1
# 3                     8                        4                 4
# 4                     5                        7                 7
# ...                 ...                      ...               ...
# 1195                  7                        6                 5
# 1196                  7                        6                 4
# 1197                  9                        3                 7
# 1198                  1                        3                 7
# 1199                  6                        4                 8
#
# [1200 rows x 21 columns]

# %%
ndf = process(df)
ndf
# Out:
#       Age  Gender  Education_Level  Employment_Status  Sleep_Hours  \
# 0      56       0                0                  0          6.0
# 1      69       1                0                  1          8.8
# 2      46       1                1                  2          5.3
# 3      32       1                2                  0          8.8
# 4      60       1                0                  1          7.2
# ...   ...     ...              ...                ...          ...
# 1195   23       1                3                  3          5.1
# 1196   43       1                1                  2          8.9
# 1197   71       1                4                  1          6.0
# 1198   21       0                3                  2          8.5
# 1199   36       0                3                  2          4.4
#
#       Physical_Activity_Hrs  Social_Support_Score  Anxiety_Score  \
# 0                       0.4                     3              4
# 1                       2.8                     6             18
# 2                       1.6                     5              5
# 3                       0.5                     4              6
# 4                       0.7                     2              7
# ...                     ...                   ...            ...
# 1195                    0.1                     7             16
# 1196                    0.4                     9             19
# 1197                    0.1                     2             15
# 1198                    2.7                     8             12
# 1199                    2.6                     7             10
#
#       Depression_Score  Stress_Level  ...  Chronic_Illnesses  Medication_Use  \
# 0                    2             9  ...                  0               0
# 1                    7             6  ...                  0               0
# 2                   13             8  ...                  0               0
# 3                    3             4  ...                  1               0
# 4                   15             3  ...                  0               0
# ...                ...           ...  ...                ...             ...
# 1195                15             5  ...                  0               1
# 1196                 4             9  ...                  0               0
# 1197                 4             2  ...                  0               0
# 1198                20             2  ...                  1               0
# 1199                10             5  ...                  0               0
#
#       Therapy  Meditation  Substance_Use  Financial_Stress  Work_Stress  \
# 0           0           1              0                 4            3
# 1           1           0              0                 1            4
# 2           0           1              0                 8            7
# 3           0           0              0                 7            4
# 4           1           1              1                 8            9
# ...       ...         ...            ...               ...          ...
# 1195        0           0              0                 2            8
# 1196        0           1              0                 8            9
# 1197        0           1              0                 2            9
# 1198        0           0              0                 8            5
# 1199        1           0              1                 7            2
#
#       Self_Esteem_Score  Life_Satisfaction_Score  Loneliness_Score
# 0                     7                        5                 1
# 1                     7                        4                 6
# 2                     8                        1                 1
# 3                     8                        4                 4
# 4                     5                        7                 7
# ...                 ...                      ...               ...
# 1195                  7                        6                 5
# 1196                  7                        6                 4
# 1197                  9                        3                 7
# 1198                  1                        3                 7
# 1199                  6                        4                 8
#
# [1200 rows x 21 columns]
